# %%
import pandas as pd

import config

df = pd.read_csv("disponibili/A&T_Disp_2WheelsPoliTO.csv")

# %%
def filtra_disponibili(
    df: pd.DataFrame,
    giorno: str,
    fascia: str
) -> pd.DataFrame:

    disponibilità = config.MAP_COLONNE_DISPONIBILITA[giorno][fascia]
    return df[df[disponibili] == 1].copy()
