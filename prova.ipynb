# %%
import pandas as pd

import config

df = pd.read_csv("disponibili/A&T_Disp_2WheelsPoliTO.csv", sep=';', encoding='latin1')
df
# Out:
#                Nome   Cognome Matricola       Reparto NEW 2026  MeMatt  MePom  \
# 0           Antonio      Mele   s348338  AERODINAMICA       NO     NaN    NaN
# 1   Davide Vincenzo  Piccinni   s322868  AERODINAMICA       NO     NaN    NaN
# 2             Fabio  Rapalino   s328471  AERODINAMICA       NO     NaN    NaN
# 3          Giovanni  Castagna   s333934  AERODINAMICA       NO     NaN    NaN
# 4            Giulio   Capanna   s347023  AERODINAMICA       NO     NaN    NaN
# ..              ...       ...       ...           ...      ...     ...    ...
# 94         Riccardo    Givone   s326992     STRUTTURE       NO     NaN    NaN
# 95           Simone     Sonda   s342827     STRUTTURE       NO     NaN    NaN
# 96        Stanislaw     Hudak   s321907     STRUTTURE       NO     NaN    NaN
# 97          Stefano  De Marco   s359140     STRUTTURE       NO     NaN    NaN
# 98            Marco   Biagini   s317994           NaN       NO     NaN    NaN
#
#     GioMatt  GioPomm  VeMatt  VePom  Unnamed: 11
# 0       NaN      NaN     NaN    NaN          NaN
# 1       NaN      NaN     NaN    NaN          NaN
# 2       NaN      NaN     NaN    1.0          NaN
# 3       NaN      NaN     NaN    NaN          NaN
# 4       NaN      NaN     NaN    NaN          NaN
# ..      ...      ...     ...    ...          ...
# 94      NaN      NaN     NaN    NaN          NaN
# 95      NaN      NaN     NaN    NaN          NaN
# 96      NaN      NaN     NaN    NaN          NaN
# 97      NaN      1.0     1.0    NaN          NaN
# 98      NaN      NaN     NaN    NaN          NaN
#
# [99 rows x 12 columns]

# %%
def filtra_disponibili(
    df: pd.DataFrame,
    giorno: str,
    fascia: str
) -> pd.DataFrame:

    disponibilità = config.MAP_COLONNE_DISPONIBILITA[giorno][fascia]
    return df[df[disponibili] == 1].copy()
